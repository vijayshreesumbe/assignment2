# %%
class Node:
    """A class to represent a node in a singly linked list."""
    def __init__(self, data):
        self.data = data
        self.next = None
class LinkedList:
    """A class to manage the singly linked list."""
    def __init__(self):
        self.head = None
    def add_node(self, data):
        """Add a node with the given data to the end of the list."""
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            print(f"Added '{data}' as head node.")
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            print(f"Added '{data}' to the end of the list.")
    def print_list(self):
        """Print all the elements in the linked list."""
        if not self.head:
            print("The list is empty.")
        else:
            current = self.head
            print("Linked List:", end=" ")
            while current:
                print(current.data, end=" -> ")
                current = current.next
            print("None")
    def delete_nth_node(self, n):
        """Delete the nth node (1-based index) from the linked list."""
        try:
            if not self.head:
                raise Exception("Cannot delete from an empty list.")

            if n <= 0:
                raise IndexError("Index must be 1 or greater.")

            if n == 1:
                print(f"Deleted node with value '{self.head.data}' at position 1.")
                self.head = self.head.next
                return
            current = self.head
            for i in range(n - 2):
                if current.next is None:
                    raise IndexError("Index out of range.")
                current = current.next
            if current.next is None:
                raise IndexError("Index out of range.")
            print(f"Deleted node with value '{current.next.data}' at position {n}.")
            current.next = current.next.next
        except Exception as e:
            print("Error:", e)
if __name__ == "__main__":
    ll = LinkedList()
    ll.add_node(10)
    ll.add_node(20)
    ll.add_node(30)
    ll.add_node(40)
    ll.print_list()
    ll.delete_nth_node(2) 
    ll.print_list()
    ll.delete_nth_node(10)  
    ll.delete_nth_node(0)   
    ll.delete_nth_node(1)   
    ll.delete_nth_node(1)   
    ll.delete_nth_node(1)   
    ll.delete_nth_node(1)   

    ll.print_list()
# Out:
# Added '10' as head node.
# Added '20' to the end of the list.
# Added '30' to the end of the list.
# Added '40' to the end of the list.
# Linked List: 10 -> 20 -> 30 -> 40 -> None
# Deleted node with value '20' at position 2.
# Linked List: 10 -> 30 -> 40 -> None
# Error: Index out of range.
# Error: Index must be 1 or greater.
# Deleted node with value '10' at position 1.
# Deleted node with value '30' at position 1.
# Deleted node with value '40' at position 1.
# Error: Cannot delete from an empty list.
# The list is empty.
